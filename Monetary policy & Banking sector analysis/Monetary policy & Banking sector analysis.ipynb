# %%
import pandas as pd
import statsmodels.formula.api as smf
from pathlib import Path

# %%
data_path = Path('merged_data_with_inflation.csv')
df = pd.read_csv(data_path)

df = df.dropna(subset=['Country'])

df['Country'] = df['Country'].astype('category')

# %%
#Define regression function
def run_reg(dep_var, rate_vars, data=df):
    needed = [dep_var] + rate_vars + ['Inflation', 'GDP_per_capita', 'Country']
    data_clean = data.dropna(subset=needed)

    formula = (
        f"{dep_var} ~ "
        + " + ".join(rate_vars)
        + " + Inflation + GDP_per_capita + C(Country)"
    )

    model = smf.ols(formula, data=data_clean).fit(
        cov_type='cluster',
        cov_kwds={'groups': data_clean['Country']}
    )
    return model

#Regressions 

dependents = ['households_avg','corp_avg','loans_sum','avg_nim', 'imp_sum']
policy_specs = {
    'all_rates': ['MRO', 'DFR', 'MLF'],
    'MRO_only':  ['MRO'],
    'DFR_only':  ['DFR'],
    'MLF_only':  ['MLF'],
}

results = {}
for dep in dependents:
    results[dep] = {}
    for spec_name, rate_vars in policy_specs.items():
        results[dep][spec_name] = run_reg(dep, rate_vars)


#Results
for dep, res_dict in results.items():
    print('\n' + '='*80)
    print(f'Dependent variable: {dep}')
    print('='*80)
    for spec, model in res_dict.items():
        print(f'\n--- Specification: {spec} ---')
        print(model.summary())
        print('\n')
# Out:
# ================================================================================
# Dependent variable: households_avg
# ================================================================================
#
# --- Specification: all_rates ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         households_avg   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                 3.676e+04
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           1.18e-33
# Time:                        16:55:17   Log-Likelihood:                 11.004
# No. Observations:                 342   AIC:                             23.99
# Df Residuals:                     319   BIC:                             112.2
# Df Model:                          22
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     6.0545      0.208     29.086      0.000       5.647       6.463
# C(Country)[T.Belgium]         0.0157      0.011      1.445      0.149      -0.006       0.037
# C(Country)[T.Cyprus]          0.0692      0.048      1.437      0.151      -0.025       0.164
# C(Country)[T.Estonia]         0.0531      0.077      0.688      0.492      -0.098       0.204
# C(Country)[T.Finland]         0.0321      0.020      1.642      0.101      -0.006       0.070
# C(Country)[T.France]          0.0461      0.030      1.537      0.124      -0.013       0.105
# C(Country)[T.Germany]         0.0124      0.005      2.436      0.015       0.002       0.022
# C(Country)[T.Greece]          0.0991      0.077      1.282      0.200      -0.052       0.250
# C(Country)[T.Ireland]        -0.0616      0.072     -0.850      0.395      -0.204       0.080
# C(Country)[T.Italy]           0.0506      0.037      1.368      0.171      -0.022       0.123
# C(Country)[T.Latvia]          0.0763      0.099      0.768      0.443      -0.119       0.271
# C(Country)[T.Lithuania]       0.0617      0.080      0.767      0.443      -0.096       0.219
# C(Country)[T.Luxembourg]     -0.2327      0.210     -1.107      0.268      -0.645       0.179
# C(Country)[T.Malta]           0.0573      0.045      1.280      0.200      -0.030       0.145
# C(Country)[T.Netherlands]    -0.0088      0.014     -0.651      0.515      -0.035       0.018
# C(Country)[T.Portugal]        0.0921      0.071      1.299      0.194      -0.047       0.231
# C(Country)[T.Slovakia]        0.0856      0.083      1.028      0.304      -0.078       0.249
# C(Country)[T.Slovenia]        0.0700      0.060      1.161      0.246      -0.048       0.188
# C(Country)[T.Spain]        -7.01e-32   3.73e-28     -0.000      1.000   -7.32e-28    7.32e-28
# MRO                          -6.7713      0.225    -30.042      0.000      -7.213      -6.330
# DFR                           3.6743      0.082     45.040      0.000       3.514       3.834
# MLF                           3.5549      0.139     25.542      0.000       3.282       3.828
# Inflation                     0.0166      0.005      3.350      0.001       0.007       0.026
# GDP_per_capita             5.743e-06   5.12e-06      1.122      0.262   -4.29e-06    1.58e-05
# ==============================================================================
# Omnibus:                        3.282   Durbin-Watson:                   1.221
# Prob(Omnibus):                  0.194   Jarque-Bera (JB):                3.360
# Skew:                           0.225   Prob(JB):                        0.186
# Kurtosis:                       2.816   Cond. No.                     6.29e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.1e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# --- Specification: MRO_only ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         households_avg   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.791
# Method:                 Least Squares   F-statistic:                     2305.
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           2.22e-22
# Time:                        16:55:17   Log-Likelihood:                -138.79
# No. Observations:                 342   AIC:                             319.6
# Df Residuals:                     321   BIC:                             400.1
# Df Model:                          20
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     7.0764      0.277     25.566      0.000       6.534       7.619
# C(Country)[T.Belgium]        -0.0680      0.016     -4.370      0.000      -0.098      -0.037
# C(Country)[T.Cyprus]         -0.3004      0.069     -4.361      0.000      -0.435      -0.165
# C(Country)[T.Estonia]        -0.4315      0.120     -3.599      0.000      -0.667      -0.197
# C(Country)[T.Finland]        -0.1246      0.027     -4.599      0.000      -0.178      -0.072
# C(Country)[T.France]         -0.1890      0.042     -4.475      0.000      -0.272      -0.106
# C(Country)[T.Germany]        -0.0342      0.006     -5.728      0.000      -0.046      -0.023
# C(Country)[T.Greece]         -0.4728      0.113     -4.193      0.000      -0.694      -0.252
# C(Country)[T.Ireland]         0.4165      0.111      3.754      0.000       0.199       0.634
# C(Country)[T.Italy]          -0.2288      0.053     -4.285      0.000      -0.333      -0.124
# C(Country)[T.Latvia]         -0.5636      0.153     -3.675      0.000      -0.864      -0.263
# C(Country)[T.Lithuania]      -0.4555      0.124     -3.674      0.000      -0.698      -0.213
# C(Country)[T.Luxembourg]      1.2567      0.313      4.009      0.000       0.642       1.871
# C(Country)[T.Malta]          -0.2738      0.065     -4.190      0.000      -0.402      -0.146
# C(Country)[T.Netherlands]     0.0754      0.021      3.565      0.000       0.034       0.117
# C(Country)[T.Portugal]       -0.4347      0.103     -4.211      0.000      -0.637      -0.232
# C(Country)[T.Slovakia]       -0.4919      0.125     -3.930      0.000      -0.737      -0.247
# C(Country)[T.Slovenia]       -0.3632      0.089     -4.065      0.000      -0.538      -0.188
# C(Country)[T.Spain]        7.076e-31   4.22e-29      0.017      0.987   -8.21e-29    8.35e-29
# MRO                           0.4913      0.009     56.444      0.000       0.474       0.508
# Inflation                    -0.0083      0.006     -1.417      0.156      -0.020       0.003
# GDP_per_capita            -3.066e-05   7.62e-06     -4.025      0.000   -4.56e-05   -1.57e-05
# ==============================================================================
# Omnibus:                       68.576   Durbin-Watson:                   0.580
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               14.805
# Skew:                           0.064   Prob(JB):                     0.000610
# Kurtosis:                       1.989   Cond. No.                     5.13e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.65e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# --- Specification: DFR_only ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         households_avg   R-squared:                       0.801
# Model:                            OLS   Adj. R-squared:                  0.789
# Method:                 Least Squares   F-statistic:                     1958.
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           8.85e-22
# Time:                        16:55:17   Log-Likelihood:                -140.61
# No. Observations:                 342   AIC:                             323.2
# Df Residuals:                     321   BIC:                             403.7
# Df Model:                          20
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     7.6667      0.365     20.980      0.000       6.951       8.383
# C(Country)[T.Belgium]        -0.0862      0.021     -4.128      0.000      -0.127      -0.045
# C(Country)[T.Cyprus]         -0.3811      0.092     -4.122      0.000      -0.562      -0.200
# C(Country)[T.Estonia]        -0.5752      0.158     -3.644      0.000      -0.885      -0.266
# C(Country)[T.Finland]        -0.1561      0.037     -4.266      0.000      -0.228      -0.084
# C(Country)[T.France]         -0.2383      0.057     -4.191      0.000      -0.350      -0.127
# C(Country)[T.Germany]        -0.0407      0.008     -4.928      0.000      -0.057      -0.025
# C(Country)[T.Greece]         -0.6057      0.151     -4.018      0.000      -0.901      -0.310
# C(Country)[T.Ireland]         0.5490      0.147      3.743      0.000       0.262       0.836
# C(Country)[T.Italy]          -0.2915      0.072     -4.075      0.000      -0.432      -0.151
# C(Country)[T.Latvia]         -0.7470      0.202     -3.693      0.000      -1.144      -0.351
# C(Country)[T.Lithuania]      -0.6037      0.163     -3.693      0.000      -0.924      -0.283
# C(Country)[T.Luxembourg]      1.6282      0.417      3.904      0.000       0.811       2.446
# C(Country)[T.Malta]          -0.3508      0.087     -4.017      0.000      -0.522      -0.180
# C(Country)[T.Netherlands]     0.1008      0.028      3.622      0.000       0.046       0.155
# C(Country)[T.Portugal]       -0.5562      0.138     -4.030      0.000      -0.827      -0.286
# C(Country)[T.Slovakia]       -0.6406      0.166     -3.854      0.000      -0.966      -0.315
# C(Country)[T.Slovenia]       -0.4689      0.119     -3.939      0.000      -0.702      -0.236
# C(Country)[T.Spain]        4.314e-31   3.71e-28      0.001      0.999   -7.27e-28    7.28e-28
# DFR                           0.5428      0.009     57.638      0.000       0.524       0.561
# Inflation                    -0.0018      0.007     -0.271      0.786      -0.015       0.011
# GDP_per_capita            -3.968e-05   1.01e-05     -3.914      0.000   -5.96e-05   -1.98e-05
# ==============================================================================
# Omnibus:                       25.978   Durbin-Watson:                   0.536
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               13.672
# Skew:                           0.314   Prob(JB):                      0.00107
# Kurtosis:                       2.249   Cond. No.                     1.79e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.36e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# --- Specification: MLF_only ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         households_avg   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     5037.
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           2.93e-25
# Time:                        16:55:17   Log-Likelihood:                -124.56
# No. Observations:                 342   AIC:                             291.1
# Df Residuals:                     321   BIC:                             371.6
# Df Model:                          20
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     6.4518      0.155     41.738      0.000       6.149       6.755
# C(Country)[T.Belgium]        -0.0422      0.009     -4.962      0.000      -0.059      -0.026
# C(Country)[T.Cyprus]         -0.1864      0.038     -4.947      0.000      -0.260      -0.113
# C(Country)[T.Estonia]        -0.2504      0.069     -3.651      0.000      -0.385      -0.116
# C(Country)[T.Finland]        -0.0786      0.015     -5.365      0.000      -0.107      -0.050
# C(Country)[T.France]         -0.1182      0.023     -5.146      0.000      -0.163      -0.073
# C(Country)[T.Germany]        -0.0229      0.003     -7.344      0.000      -0.029      -0.017
# C(Country)[T.Greece]         -0.2896      0.062     -4.653      0.000      -0.412      -0.168
# C(Country)[T.Ireland]         0.2456      0.063      3.908      0.000       0.122       0.369
# C(Country)[T.Italy]          -0.1412      0.029     -4.814      0.000      -0.199      -0.084
# C(Country)[T.Latvia]         -0.3297      0.087     -3.776      0.000      -0.501      -0.159
# C(Country)[T.Lithuania]      -0.2664      0.071     -3.775      0.000      -0.405      -0.128
# C(Country)[T.Luxembourg]      0.7585      0.175      4.338      0.000       0.416       1.101
# C(Country)[T.Malta]          -0.1677      0.036     -4.649      0.000      -0.238      -0.097
# C(Country)[T.Netherlands]     0.0436      0.012      3.595      0.000       0.020       0.067
# C(Country)[T.Portugal]       -0.2667      0.057     -4.685      0.000      -0.378      -0.155
# C(Country)[T.Slovakia]       -0.2948      0.070     -4.203      0.000      -0.432      -0.157
# C(Country)[T.Slovenia]       -0.2202      0.050     -4.433      0.000      -0.318      -0.123
# C(Country)[T.Spain]        3.759e-31   1.42e-29      0.027      0.979   -2.74e-29    2.81e-29
# MLF                           0.4433      0.006     73.379      0.000       0.431       0.455
# Inflation                    -0.0106      0.005     -2.307      0.021      -0.020      -0.002
# GDP_per_capita            -1.853e-05   4.24e-06     -4.365      0.000   -2.68e-05   -1.02e-05
# ==============================================================================
# Omnibus:                      132.011   Durbin-Watson:                   0.688
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.912
# Skew:                          -0.094   Prob(JB):                     7.82e-05
# Kurtosis:                       1.863   Cond. No.                     6.66e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 9.78e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# ================================================================================
# Dependent variable: corp_avg
# ================================================================================
#
# --- Specification: all_rates ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               corp_avg   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                 1.035e+05
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           1.78e-37
# Time:                        16:55:17   Log-Likelihood:                 223.46
# No. Observations:                 342   AIC:                            -400.9
# Df Residuals:                     319   BIC:                            -312.7
# Df Model:                          22
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     2.1161      0.075     28.130      0.000       1.969       2.264
# C(Country)[T.Belgium]         0.0063      0.004      1.669      0.095      -0.001       0.014
# C(Country)[T.Cyprus]          0.0276      0.017      1.641      0.101      -0.005       0.061
# C(Country)[T.Estonia]        -0.0213      0.030     -0.699      0.484      -0.081       0.038
# C(Country)[T.Finland]         0.0159      0.007      2.396      0.017       0.003       0.029
# C(Country)[T.France]          0.0207      0.010      2.003      0.045       0.000       0.041
# C(Country)[T.Germany]         0.0091      0.002      5.497      0.000       0.006       0.012
# C(Country)[T.Greece]          0.0305      0.028      1.103      0.270      -0.024       0.085
# C(Country)[T.Ireland]         0.0069      0.028      0.248      0.804      -0.048       0.061
# C(Country)[T.Italy]           0.0182      0.013      1.397      0.162      -0.007       0.044
# C(Country)[T.Latvia]         -0.0186      0.039     -0.481      0.630      -0.095       0.057
# C(Country)[T.Lithuania]      -0.0151      0.031     -0.482      0.630      -0.076       0.046
# C(Country)[T.Luxembourg]     -0.0408      0.077     -0.527      0.598      -0.192       0.111
# C(Country)[T.Malta]           0.0175      0.016      1.096      0.273      -0.014       0.049
# C(Country)[T.Netherlands]     0.0043      0.005      0.796      0.426      -0.006       0.015
# C(Country)[T.Portugal]        0.0293      0.025      1.161      0.246      -0.020       0.079
# C(Country)[T.Slovakia]        0.0087      0.031      0.281      0.778      -0.052       0.069
# C(Country)[T.Slovenia]        0.0154      0.022      0.700      0.484      -0.028       0.058
# C(Country)[T.Spain]        2.041e-32   2.01e-28      0.000      1.000   -3.95e-28    3.95e-28
# MRO                          -5.1162      0.089    -57.753      0.000      -5.290      -4.943
# DFR                           3.2081      0.032     99.109      0.000       3.145       3.272
# MLF                           2.7805      0.055     50.250      0.000       2.672       2.889
# Inflation                     0.0200      0.003      6.762      0.000       0.014       0.026
# GDP_per_capita              1.08e-06   1.88e-06      0.576      0.565    -2.6e-06    4.76e-06
# ==============================================================================
# Omnibus:                       66.702   Durbin-Watson:                   1.570
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.669
# Skew:                           0.318   Prob(JB):                     5.36e-05
# Kurtosis:                       2.012   Cond. No.                     6.29e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.1e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# --- Specification: MRO_only ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               corp_avg   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                 1.604e+04
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           1.56e-29
# Time:                        16:55:17   Log-Likelihood:                -23.732
# No. Observations:                 342   AIC:                             89.46
# Df Residuals:                     321   BIC:                             170.0
# Df Model:                          20
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     2.5619      0.205     12.521      0.000       2.161       2.963
# C(Country)[T.Belgium]        -0.0483      0.012     -4.167      0.000      -0.071      -0.026
# C(Country)[T.Cyprus]         -0.2133      0.051     -4.161      0.000      -0.314      -0.113
# C(Country)[T.Estonia]        -0.3166      0.087     -3.640      0.000      -0.487      -0.146
# C(Country)[T.Finland]        -0.0878      0.020     -4.315      0.000      -0.128      -0.048
# C(Country)[T.France]         -0.1337      0.032     -4.235      0.000      -0.196      -0.072
# C(Country)[T.Germany]        -0.0233      0.005     -4.985      0.000      -0.032      -0.014
# C(Country)[T.Greece]         -0.3379      0.083     -4.050      0.000      -0.501      -0.174
# C(Country)[T.Ireland]         0.3034      0.081      3.750      0.000       0.145       0.462
# C(Country)[T.Italy]          -0.1629      0.040     -4.111      0.000      -0.241      -0.085
# C(Country)[T.Latvia]         -0.4120      0.112     -3.694      0.000      -0.631      -0.193
# C(Country)[T.Lithuania]      -0.3330      0.090     -3.694      0.000      -0.510      -0.156
# C(Country)[T.Luxembourg]      0.9049      0.230      3.926      0.000       0.453       1.357
# C(Country)[T.Malta]          -0.1957      0.048     -4.048      0.000      -0.290      -0.101
# C(Country)[T.Netherlands]     0.0554      0.015      3.616      0.000       0.025       0.085
# C(Country)[T.Portugal]       -0.3104      0.076     -4.062      0.000      -0.460      -0.161
# C(Country)[T.Slovakia]       -0.3554      0.092     -3.872      0.000      -0.535      -0.175
# C(Country)[T.Slovenia]       -0.2609      0.066     -3.964      0.000      -0.390      -0.132
# C(Country)[T.Spain]        3.283e-31   1.29e-29      0.026      0.980   -2.49e-29    2.55e-29
# MRO                           0.8638      0.006    142.008      0.000       0.852       0.876
# Inflation                    -0.0027      0.004     -0.685      0.493      -0.010       0.005
# GDP_per_capita            -2.206e-05    5.6e-06     -3.937      0.000    -3.3e-05   -1.11e-05
# ==============================================================================
# Omnibus:                       29.166   Durbin-Watson:                   0.620
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.124
# Skew:                           0.623   Prob(JB):                     1.29e-06
# Kurtosis:                       2.407   Cond. No.                     5.13e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.65e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# --- Specification: DFR_only ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               corp_avg   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     6572.
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           3.06e-26
# Time:                        16:55:17   Log-Likelihood:                -22.146
# No. Observations:                 342   AIC:                             86.29
# Df Residuals:                     321   BIC:                             166.8
# Df Model:                          20
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     3.5958      0.370      9.723      0.000       2.871       4.321
# C(Country)[T.Belgium]        -0.0801      0.021     -3.780      0.000      -0.122      -0.039
# C(Country)[T.Cyprus]         -0.3546      0.094     -3.778      0.000      -0.539      -0.171
# C(Country)[T.Estonia]        -0.5667      0.157     -3.611      0.000      -0.874      -0.259
# C(Country)[T.Finland]        -0.1429      0.037     -3.825      0.000      -0.216      -0.070
# C(Country)[T.France]         -0.2200      0.058     -3.801      0.000      -0.333      -0.107
# C(Country)[T.Germany]        -0.0348      0.009     -4.020      0.000      -0.052      -0.018
# C(Country)[T.Greece]         -0.5702      0.152     -3.743      0.000      -0.869      -0.272
# C(Country)[T.Ireland]         0.5342      0.146      3.647      0.000       0.247       0.821
# C(Country)[T.Italy]          -0.2727      0.072     -3.762      0.000      -0.415      -0.131
# C(Country)[T.Latvia]         -0.7315      0.202     -3.629      0.000      -1.127      -0.336
# C(Country)[T.Lithuania]      -0.5912      0.163     -3.629      0.000      -0.911      -0.272
# C(Country)[T.Luxembourg]      1.5536      0.419      3.704      0.000       0.732       2.376
# C(Country)[T.Malta]          -0.3303      0.088     -3.743      0.000      -0.503      -0.157
# C(Country)[T.Netherlands]     0.0996      0.028      3.603      0.000       0.045       0.154
# C(Country)[T.Portugal]       -0.5230      0.140     -3.747      0.000      -0.797      -0.249
# C(Country)[T.Slovakia]       -0.6149      0.167     -3.687      0.000      -0.942      -0.288
# C(Country)[T.Slovenia]       -0.4456      0.120     -3.716      0.000      -0.681      -0.211
# C(Country)[T.Spain]         3.02e-31   2.32e-28      0.001      0.999   -4.54e-28    4.54e-28
# DFR                           0.9566      0.009    111.825      0.000       0.940       0.973
# Inflation                     0.0083      0.006      1.465      0.143      -0.003       0.019
# GDP_per_capita            -3.782e-05   1.02e-05     -3.707      0.000   -5.78e-05   -1.78e-05
# ==============================================================================
# Omnibus:                       16.194   Durbin-Watson:                   0.497
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.605
# Skew:                           0.556   Prob(JB):                     0.000150
# Kurtosis:                       2.989   Cond. No.                     1.79e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.36e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# --- Specification: MLF_only ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               corp_avg   R-squared:                       0.955
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                 5.482e+05
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           1.44e-42
# Time:                        16:55:17   Log-Likelihood:                -32.775
# No. Observations:                 342   AIC:                             107.6
# Df Residuals:                     321   BIC:                             188.1
# Df Model:                          20
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     1.5272      0.060     25.360      0.000       1.409       1.645
# C(Country)[T.Belgium]        -0.0052      0.003     -1.711      0.087      -0.011       0.001
# C(Country)[T.Cyprus]         -0.0229      0.013     -1.699      0.089      -0.049       0.004
# C(Country)[T.Estonia]        -0.0248      0.030     -0.834      0.404      -0.083       0.033
# C(Country)[T.Finland]        -0.0101      0.005     -2.057      0.040      -0.020      -0.000
# C(Country)[T.France]         -0.0148      0.008     -1.864      0.062      -0.030       0.001
# C(Country)[T.Germany]        -0.0034      0.001     -3.908      0.000      -0.005      -0.002
# C(Country)[T.Greece]         -0.0343      0.023     -1.472      0.141      -0.080       0.011
# C(Country)[T.Ireland]         0.0257      0.026      0.979      0.327      -0.026       0.077
# C(Country)[T.Italy]          -0.0170      0.011     -1.594      0.111      -0.038       0.004
# C(Country)[T.Latvia]         -0.0336      0.037     -0.903      0.367      -0.107       0.039
# C(Country)[T.Lithuania]      -0.0271      0.030     -0.903      0.367      -0.086       0.032
# C(Country)[T.Luxembourg]      0.0858      0.069      1.250      0.211      -0.049       0.220
# C(Country)[T.Malta]          -0.0198      0.013     -1.469      0.142      -0.046       0.007
# C(Country)[T.Netherlands]     0.0043      0.005      0.803      0.422      -0.006       0.015
# C(Country)[T.Portugal]       -0.0317      0.021     -1.495      0.135      -0.073       0.010
# C(Country)[T.Slovakia]       -0.0326      0.028     -1.161      0.246      -0.088       0.022
# C(Country)[T.Slovenia]       -0.0253      0.019     -1.315      0.189      -0.063       0.012
# C(Country)[T.Spain]        1.772e-31   4.44e-30      0.040      0.968   -8.53e-30    8.88e-30
# MLF                           0.7664      0.004    196.710      0.000       0.759       0.774
# Inflation                    -0.0032      0.003     -0.939      0.348      -0.010       0.003
# GDP_per_capita            -2.104e-06   1.66e-06     -1.268      0.205   -5.36e-06    1.15e-06
# ==============================================================================
# Omnibus:                       20.478   Durbin-Watson:                   0.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.839
# Skew:                           0.563   Prob(JB):                     2.98e-05
# Kurtosis:                       2.561   Cond. No.                     6.66e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 9.78e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# ================================================================================
# Dependent variable: loans_sum
# ================================================================================
#
# --- Specification: all_rates ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              loans_sum   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                 1.381e+04
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           4.84e-30
# Time:                        16:55:17   Log-Likelihood:                -7189.2
# No. Observations:                 342   AIC:                         1.442e+04
# Df Residuals:                     319   BIC:                         1.451e+04
# Df Model:                          22
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  9.341e+08   2.28e+08      4.104      0.000    4.88e+08    1.38e+09
# C(Country)[T.Belgium]      3.799e+08   1.06e+07     35.858      0.000    3.59e+08    4.01e+08
# C(Country)[T.Cyprus]      -6.796e+08   4.69e+07    -14.482      0.000   -7.72e+08   -5.88e+08
# C(Country)[T.Estonia]     -7.327e+08   8.24e+07     -8.888      0.000   -8.94e+08   -5.71e+08
# C(Country)[T.Finland]     -6.466e+08   1.85e+07    -35.020      0.000   -6.83e+08    -6.1e+08
# C(Country)[T.France]       5.988e+09   2.88e+07    208.148      0.000    5.93e+09    6.04e+09
# C(Country)[T.Germany]      4.743e+09   4.16e+06   1140.947      0.000    4.74e+09    4.75e+09
# C(Country)[T.Greece]      -6.816e+08   7.69e+07     -8.866      0.000   -8.32e+08   -5.31e+08
# C(Country)[T.Ireland]     -9.815e+07   7.61e+07     -1.291      0.197   -2.47e+08    5.09e+07
# C(Country)[T.Italy]        1.169e+09   3.64e+07     32.135      0.000     1.1e+09    1.24e+09
# C(Country)[T.Latvia]      -7.764e+08   1.05e+08     -7.374      0.000   -9.83e+08    -5.7e+08
# C(Country)[T.Lithuania]   -7.429e+08   8.51e+07     -8.731      0.000    -9.1e+08   -5.76e+08
# C(Country)[T.Luxembourg]  -2.246e+08   2.14e+08     -1.049      0.294   -6.44e+08    1.95e+08
# C(Country)[T.Malta]       -6.911e+08   4.45e+07    -15.515      0.000   -7.78e+08   -6.04e+08
# C(Country)[T.Netherlands]  1.645e+09   1.46e+07    113.069      0.000    1.62e+09    1.67e+09
# C(Country)[T.Portugal]    -6.733e+08   7.04e+07     -9.567      0.000   -8.11e+08   -5.35e+08
# C(Country)[T.Slovakia]    -7.254e+08   8.56e+07     -8.477      0.000   -8.93e+08   -5.58e+08
# C(Country)[T.Slovenia]    -7.195e+08    6.1e+07    -11.797      0.000   -8.39e+08      -6e+08
# C(Country)[T.Spain]        5.113e-07   2.12e-19   2.41e+12      0.000    5.11e-07    5.11e-07
# MRO                         1.29e+09   8.02e+08      1.609      0.108   -2.81e+08    2.86e+09
# DFR                       -5.292e+08    3.2e+08     -1.654      0.098   -1.16e+09     9.8e+07
# MLF                       -7.329e+08   4.73e+08     -1.551      0.121   -1.66e+09    1.93e+08
# Inflation                  4.775e+06   5.07e+06      0.941      0.347   -5.17e+06    1.47e+07
# GDP_per_capita            -7430.0317   5201.294     -1.428      0.153   -1.76e+04    2764.317
# ==============================================================================
# Omnibus:                      230.903   Durbin-Watson:                   0.732
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12796.219
# Skew:                          -2.087   Prob(JB):                         0.00
# Kurtosis:                      32.674   Cond. No.                     6.29e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.1e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# --- Specification: MRO_only ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              loans_sum   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     9385.
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           1.48e-27
# Time:                        16:55:17   Log-Likelihood:                -7195.4
# No. Observations:                 342   AIC:                         1.443e+04
# Df Residuals:                     321   BIC:                         1.451e+04
# Df Model:                          20
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  4.819e+08   2.39e+08      2.016      0.044    1.33e+07    9.51e+08
# C(Country)[T.Belgium]      4.046e+08   1.44e+07     28.110      0.000    3.76e+08    4.33e+08
# C(Country)[T.Cyprus]      -5.704e+08   6.36e+07     -8.966      0.000   -6.95e+08   -4.46e+08
# C(Country)[T.Estonia]     -5.755e+08   9.39e+07     -6.127      0.000    -7.6e+08   -3.91e+08
# C(Country)[T.Finland]     -6.013e+08   2.65e+07    -22.733      0.000   -6.53e+08   -5.49e+08
# C(Country)[T.France]       6.057e+09      4e+07    151.232      0.000    5.98e+09    6.14e+09
# C(Country)[T.Germany]      4.756e+09   7.57e+06    628.421      0.000    4.74e+09    4.77e+09
# C(Country)[T.Greece]      -5.098e+08      1e+08     -5.087      0.000   -7.06e+08   -3.13e+08
# C(Country)[T.Ireland]     -2.497e+08   8.97e+07     -2.786      0.005   -4.25e+08    -7.4e+07
# C(Country)[T.Italy]        1.252e+09   4.85e+07     25.844      0.000    1.16e+09    1.35e+09
# C(Country)[T.Latvia]      -5.713e+08   1.22e+08     -4.684      0.000    -8.1e+08   -3.32e+08
# C(Country)[T.Lithuania]   -5.771e+08   9.86e+07     -5.856      0.000    -7.7e+08   -3.84e+08
# C(Country)[T.Luxembourg]  -6.816e+08   2.67e+08     -2.549      0.011   -1.21e+09   -1.58e+08
# C(Country)[T.Malta]       -5.916e+08    5.8e+07    -10.195      0.000   -7.05e+08   -4.78e+08
# C(Country)[T.Netherlands]  1.618e+09   1.65e+07     98.282      0.000    1.59e+09    1.65e+09
# C(Country)[T.Portugal]    -5.153e+08   9.21e+07     -5.594      0.000   -6.96e+08   -3.35e+08
# C(Country)[T.Slovakia]    -5.465e+08   1.05e+08     -5.207      0.000   -7.52e+08   -3.41e+08
# C(Country)[T.Slovenia]    -5.874e+08   7.72e+07     -7.613      0.000   -7.39e+08   -4.36e+08
# C(Country)[T.Spain]        7.499e-08   3.26e-19    2.3e+11      0.000     7.5e-08     7.5e-08
# MRO                       -2.877e+06   1.49e+07     -0.193      0.847   -3.21e+07    2.64e+07
# Inflation                  7.704e+06   7.22e+06      1.067      0.286   -6.45e+06    2.19e+07
# GDP_per_capita             3717.6338   6519.939      0.570      0.569   -9061.211    1.65e+04
# ==============================================================================
# Omnibus:                      220.909   Durbin-Watson:                   0.749
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13615.169
# Skew:                          -1.905   Prob(JB):                         0.00
# Kurtosis:                      33.675   Cond. No.                     5.13e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.65e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# --- Specification: DFR_only ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              loans_sum   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     8726.
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           2.75e-27
# Time:                        16:55:17   Log-Likelihood:                -7195.4
# No. Observations:                 342   AIC:                         1.443e+04
# Df Residuals:                     321   BIC:                         1.451e+04
# Df Model:                          20
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  4.729e+08   2.48e+08      1.907      0.057   -1.32e+07    9.59e+08
# C(Country)[T.Belgium]      4.049e+08   1.48e+07     27.448      0.000    3.76e+08    4.34e+08
# C(Country)[T.Cyprus]      -5.691e+08   6.52e+07     -8.728      0.000   -6.97e+08   -4.41e+08
# C(Country)[T.Estonia]     -5.713e+08   9.57e+07     -5.968      0.000   -7.59e+08   -3.84e+08
# C(Country)[T.Finland]     -6.009e+08   2.71e+07    -22.184      0.000   -6.54e+08   -5.48e+08
# C(Country)[T.France]       6.057e+09    4.1e+07    147.616      0.000    5.98e+09    6.14e+09
# C(Country)[T.Germany]      4.756e+09   7.67e+06    620.422      0.000    4.74e+09    4.77e+09
# C(Country)[T.Greece]      -5.072e+08   1.03e+08     -4.939      0.000   -7.08e+08   -3.06e+08
# C(Country)[T.Ireland]     -2.533e+08   9.16e+07     -2.766      0.006   -4.33e+08   -7.38e+07
# C(Country)[T.Italy]        1.253e+09   4.97e+07     25.237      0.000    1.16e+09    1.35e+09
# C(Country)[T.Latvia]      -5.661e+08   1.24e+08     -4.549      0.000    -8.1e+08   -3.22e+08
# C(Country)[T.Lithuania]   -5.729e+08   1.01e+08     -5.697      0.000    -7.7e+08   -3.76e+08
# C(Country)[T.Luxembourg]    -6.9e+08   2.74e+08     -2.520      0.012   -1.23e+09   -1.53e+08
# C(Country)[T.Malta]       -5.901e+08   5.95e+07     -9.923      0.000   -7.07e+08   -4.74e+08
# C(Country)[T.Netherlands]  1.617e+09   1.68e+07     96.470      0.000    1.58e+09    1.65e+09
# C(Country)[T.Portugal]    -5.129e+08   9.44e+07     -5.434      0.000   -6.98e+08   -3.28e+08
# C(Country)[T.Slovakia]    -5.429e+08   1.07e+08     -5.054      0.000   -7.53e+08   -3.32e+08
# C(Country)[T.Slovenia]    -5.851e+08    7.9e+07     -7.402      0.000    -7.4e+08    -4.3e+08
# C(Country)[T.Spain]       -7.269e-07   5.28e-19  -1.38e+12      0.000   -7.27e-07   -7.27e-07
# DFR                       -1.239e+04    1.4e+07     -0.001      0.999   -2.75e+07    2.74e+07
# Inflation                  7.004e+06   6.46e+06      1.084      0.278   -5.66e+06    1.97e+07
# GDP_per_capita             3920.4264   6677.814      0.587      0.557   -9167.849     1.7e+04
# ==============================================================================
# Omnibus:                      221.588   Durbin-Watson:                   0.744
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13658.894
# Skew:                          -1.914   Prob(JB):                         0.00
# Kurtosis:                      33.722   Cond. No.                     1.79e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.36e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# --- Specification: MLF_only ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              loans_sum   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                 1.022e+04
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           7.18e-28
# Time:                        16:55:17   Log-Likelihood:                -7195.3
# No. Observations:                 342   AIC:                         1.443e+04
# Df Residuals:                     321   BIC:                         1.451e+04
# Df Model:                          20
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  5.069e+08   2.27e+08      2.231      0.026    6.16e+07    9.52e+08
# C(Country)[T.Belgium]      4.037e+08   1.37e+07     29.411      0.000    3.77e+08    4.31e+08
# C(Country)[T.Cyprus]      -5.744e+08   6.07e+07     -9.468      0.000   -6.93e+08   -4.56e+08
# C(Country)[T.Estonia]     -5.856e+08    9.1e+07     -6.433      0.000   -7.64e+08   -4.07e+08
# C(Country)[T.Finland]     -6.027e+08   2.52e+07    -23.900      0.000   -6.52e+08   -5.53e+08
# C(Country)[T.France]       6.054e+09   3.82e+07    158.580      0.000    5.98e+09    6.13e+09
# C(Country)[T.Germany]      4.756e+09   7.31e+06    650.998      0.000    4.74e+09    4.77e+09
# C(Country)[T.Greece]      -5.171e+08   9.57e+07     -5.403      0.000   -7.05e+08   -3.29e+08
# C(Country)[T.Ireland]      -2.41e+08   8.64e+07     -2.790      0.005    -4.1e+08   -7.17e+07
# C(Country)[T.Italy]        1.249e+09   4.62e+07     27.016      0.000    1.16e+09    1.34e+09
# C(Country)[T.Latvia]      -5.837e+08   1.18e+08     -4.953      0.000   -8.15e+08   -3.53e+08
# C(Country)[T.Lithuania]   -5.872e+08   9.52e+07     -6.165      0.000   -7.74e+08   -4.01e+08
# C(Country)[T.Luxembourg]  -6.595e+08   2.56e+08     -2.576      0.010   -1.16e+09   -1.58e+08
# C(Country)[T.Malta]       -5.958e+08   5.54e+07    -10.752      0.000   -7.04e+08   -4.87e+08
# C(Country)[T.Netherlands]   1.62e+09    1.6e+07    101.395      0.000    1.59e+09    1.65e+09
# C(Country)[T.Portugal]    -5.219e+08   8.79e+07     -5.934      0.000   -6.94e+08   -3.49e+08
# C(Country)[T.Slovakia]    -5.556e+08   1.01e+08     -5.520      0.000   -7.53e+08   -3.58e+08
# C(Country)[T.Slovenia]    -5.935e+08   7.38e+07     -8.041      0.000   -7.38e+08   -4.49e+08
# C(Country)[T.Spain]        2.603e-07   7.53e-19   3.45e+11      0.000     2.6e-07     2.6e-07
# MLF                       -6.956e+06   1.62e+07     -0.431      0.667   -3.86e+07    2.47e+07
# Inflation                   8.92e+06   8.13e+06      1.098      0.272      -7e+06    2.48e+07
# GDP_per_capita             3185.6245   6241.539      0.510      0.610   -9047.566    1.54e+04
# ==============================================================================
# Omnibus:                      219.659   Durbin-Watson:                   0.757
# ...
# C(Country)[T.Estonia]       -13.3846      7.362     -1.818      0.069     -27.814       1.045
# C(Country)[T.Finland]      -7.14e-14   8.26e-15     -8.646      0.000   -8.76e-14   -5.52e-14
# C(Country)[T.France]        682.6104      3.585    190.427      0.000     675.585     689.636
# C(Country)[T.Germany]        -1.0716      0.950     -1.128      0.259      -2.934       0.791
# C(Country)[T.Greece]       6.001e-14   4.96e-26   1.21e+12      0.000       6e-14       6e-14
# C(Country)[T.Ireland]        44.4211      6.925      6.415      0.000      30.849      57.994
# C(Country)[T.Italy]         202.1907      4.094     49.391      0.000     194.167     210.214
# C(Country)[T.Latvia]       1.051e-13   9.74e-26   1.08e+12      0.000    1.05e-13    1.05e-13
# C(Country)[T.Lithuania]   -1.452e-14   2.02e-26  -7.18e+11      0.000   -1.45e-14   -1.45e-14
# C(Country)[T.Luxembourg]  -2.909e-14      6e-26  -4.85e+11      0.000   -2.91e-14   -2.91e-14
# C(Country)[T.Malta]         -10.4157      4.775     -2.181      0.029     -19.774      -1.057
# C(Country)[T.Netherlands]     1.5266      1.298      1.176      0.240      -1.018       4.071
# C(Country)[T.Portugal]       -6.5448      7.621     -0.859      0.390     -21.481       8.392
# C(Country)[T.Slovakia]    -6.447e-15    3.7e-26  -1.74e+11      0.000   -6.45e-15   -6.45e-15
# C(Country)[T.Slovenia]             0          0        nan        nan           0           0
# C(Country)[T.Spain]                0          0        nan        nan           0           0
# MRO                          -6.7685      2.620     -2.583      0.010     -11.903      -1.633
# Inflation                    -1.6443      1.678     -0.980      0.327      -4.934       1.645
# GDP_per_capita               -0.0010      0.001     -1.951      0.051      -0.002    4.51e-06
# ==============================================================================
# Omnibus:                       63.849   Durbin-Watson:                   0.374
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              543.533
# Skew:                           0.877   Prob(JB):                    9.40e-119
# Kurtosis:                      10.703   Cond. No.                     1.04e+38
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 2.28e-65. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# --- Specification: DFR_only ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                imp_sum   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     2603.
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           9.25e-15
# Time:                        16:55:17   Log-Likelihood:                -1067.2
# No. Observations:                 209   AIC:                             2162.
# Df Residuals:                     195   BIC:                             2209.
# Df Model:                          13
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    46.7848     19.524      2.396      0.017       8.519      85.051
# C(Country)[T.Belgium]         3.5331      1.118      3.160      0.002       1.342       5.724
# C(Country)[T.Cyprus]          1.6586      4.925      0.337      0.736      -7.994      11.311
# C(Country)[T.Estonia]       -10.8842      6.744     -1.614      0.107     -24.101       2.333
# C(Country)[T.Finland]      5.503e-14   4.39e-15     12.539      0.000    4.64e-14    6.36e-14
# C(Country)[T.France]        683.2750      3.242    210.781      0.000     676.922     689.628
# C(Country)[T.Germany]        -1.0281      0.932     -1.104      0.270      -2.854       0.798
# C(Country)[T.Greece]       2.585e-14   8.89e-26   2.91e+11      0.000    2.59e-14    2.59e-14
# C(Country)[T.Ireland]        42.2038      6.194      6.814      0.000      30.064      54.344
# C(Country)[T.Italy]         203.0927      3.646     55.709      0.000     195.947     210.238
# C(Country)[T.Latvia]       7.474e-14   1.39e-25   5.37e+11      0.000    7.47e-14    7.47e-14
# C(Country)[T.Lithuania]    6.049e-14   4.92e-26   1.23e+12      0.000    6.05e-14    6.05e-14
# C(Country)[T.Luxembourg]   1.337e-14   4.04e-26   3.31e+11      0.000    1.34e-14    1.34e-14
# C(Country)[T.Malta]          -9.2751      4.227     -2.194      0.028     -17.559      -0.991
# C(Country)[T.Netherlands]     1.0815      1.197      0.904      0.366      -1.264       3.427
# C(Country)[T.Portugal]       -4.7551      6.754     -0.704      0.481     -17.992       8.482
# C(Country)[T.Slovakia]             0          0        nan        nan           0           0
# C(Country)[T.Slovenia]             0          0        nan        nan           0           0
# C(Country)[T.Spain]                0          0        nan        nan           0           0
# DFR                          -6.8303      2.672     -2.556      0.011     -12.067      -1.593
# Inflation                    -1.8890      1.795     -1.052      0.293      -5.407       1.629
# GDP_per_capita               -0.0009      0.000     -1.907      0.057      -0.002    2.41e-05
# ==============================================================================
# Omnibus:                       65.369   Durbin-Watson:                   0.375
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              550.599
# Skew:                           0.912   Prob(JB):                    2.75e-120
# Kurtosis:                      10.740   Cond. No.                     2.57e+38
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 3.75e-66. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
# --- Specification: MLF_only ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                imp_sum   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     2803.
# Date:                Wed, 03 Sep 2025   Prob (F-statistic):           6.40e-15
# Time:                        16:55:17   Log-Likelihood:                -1066.5
# No. Observations:                 209   AIC:                             2161.
# Df Residuals:                     195   BIC:                             2208.
# Df Model:                          13
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    62.7456     25.650      2.446      0.014      12.473     113.018
# C(Country)[T.Belgium]         2.9838      1.377      2.166      0.030       0.284       5.683
# C(Country)[T.Cyprus]         -0.7754      6.072     -0.128      0.898     -12.676      11.126
# C(Country)[T.Estonia]       -15.3265      8.035     -1.908      0.056     -31.074       0.421
# C(Country)[T.Finland]     -7.482e-14   1.17e-14     -6.421      0.000   -9.77e-14    -5.2e-14
# C(Country)[T.France]        681.7949      3.946    172.780      0.000     674.061     689.529
# C(Country)[T.Germany]        -1.2129      1.011     -1.199      0.230      -3.195       0.769
# C(Country)[T.Greece]      -2.975e-14   5.52e-26  -5.39e+11      0.000   -2.97e-14   -2.97e-14
# C(Country)[T.Ireland]        46.2796      7.632      6.064      0.000      31.321      61.239
# C(Country)[T.Italy]         201.1956      4.530     44.415      0.000     192.317     210.074
# C(Country)[T.Latvia]      -1.015e-13   5.13e-26  -1.98e+12      0.000   -1.02e-13   -1.02e-13
# C(Country)[T.Lithuania]    5.522e-14   3.42e-26   1.62e+12      0.000    5.52e-14    5.52e-14
# C(Country)[T.Luxembourg]  -1.001e-14   1.49e-26  -6.72e+11      0.000      -1e-14      -1e-14
# C(Country)[T.Malta]         -11.6115      5.294     -2.194      0.028     -21.987      -1.236
# C(Country)[T.Netherlands]     1.8665      1.413      1.321      0.187      -0.903       4.637
# C(Country)[T.Portugal]       -8.4415      8.446     -1.000      0.318     -24.995       8.112
# C(Country)[T.Slovakia]             0          0        nan        nan           0           0
# C(Country)[T.Slovenia]             0          0        nan        nan           0           0
# C(Country)[T.Spain]                0          0        nan        nan           0           0
# MLF                          -5.9577      2.226     -2.676      0.007     -10.320      -1.595
# Inflation                    -1.6580      1.700     -0.975      0.330      -4.991       1.675
# GDP_per_capita               -0.0011      0.001     -1.993      0.046      -0.002   -1.92e-05
# ==============================================================================
# Omnibus:                       62.331   Durbin-Watson:                   0.371
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              534.868
# Skew:                           0.843   Prob(JB):                    7.16e-117
# Kurtosis:                      10.653   Cond. No.                     3.53e+38
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is  2e-66. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\massi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
